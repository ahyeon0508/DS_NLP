# %% [markdown]
# 📖 참고 : 텐서플로2와 머신러닝으로 시작하는 자연어 처리

# %% [markdown]
# # 챗봇_데이터 분석(EDA)

# %% [markdown]
# ### 데이터 소개
# - [Chatbot_data_for_Korean v1.0](https://github.com/songys/Chatbot_data)
# - 총 11,876개의 데이터로 이루어짐
# - 각 데이터는 질문과 그에 대한 대답, 주제에 대한 라벨값을 가지고 있음

# %% [markdown]
# ## 1. 라이브러리 호출 및 데이터 읽기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from collections import Counter

from konlpy.tag import Okt

from functools import reduce
from wordcloud import WordCloud

# %%
DATA_IN_PATH = './data/'

data = pd.read_csv(DATA_IN_PATH + "./ChatBotData.csv", encoding = "utf-8")

# %%
data.head()
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %% [markdown]
# ## 2. EDA

# %% [markdown]
# ### 문장 전체(질문 + 답변) 길이 분석
# 음절 단위, 어절 단위, 형태소 단위로 길이를 분석함

# %%
sentences = list(data['Q']) + list(data['A'])

# %%
tokenized_sentences = [s.split() for s in sentences]
sent_len_by_token = [len(t) for t in tokenized_sentences] # 어절 단위
sent_len_by_eumjeol = [len(s.replace(" ", "")) for s in sentences] # 음절 단위

okt = Okt()

morph_tokenized_sentences = [okt.morphs(s.replace(" ", "")) for s in sentences]
sent_len_by_morph = [len(t) for t in morph_tokenized_sentences]

# %%
plt.figure(figsize=(12, 5))
plt.hist(sent_len_by_token, bins=50, range=[0,50], alpha=0.5, color= 'r', label='eojeol')
plt.hist(sent_len_by_morph, bins=50, range=[0,50], alpha=0.5, color='g', label='morph')
plt.hist(sent_len_by_eumjeol, bins=50, range=[0,50], alpha=0.5, color='b', label='eumjeol')
plt.title('Sentence Length Histogram')
plt.xlabel('Sentence Length')
plt.ylabel('Number of Sentences')
# Out:
# Text(0, 0.5, 'Number of Sentences')

# %% [markdown]
# 위의 그림은 각 히스토그램마다 y값 분포가 매우 다르기 때문에 길이가 어느 쪽으로 치우쳐 있는지 or 각 데이터에 이상치는 없는지 등의 확인 불가
# => y값의 크기를 조정해야 함

# %% [markdown]
# #### log 치환

# %%
plt.figure(figsize=(12, 5))
plt.hist(sent_len_by_token, bins=50, range=[0,50], alpha=0.5, color= 'r', label='eojeol') # alpha는 투명도를 의미함
plt.hist(sent_len_by_morph, bins=50, range=[0,50], alpha=0.5, color='g', label='morph')
plt.hist(sent_len_by_eumjeol, bins=50, range=[0,50], alpha=0.5, color='b', label='eumjeol')
plt.yscale('log')
plt.title('Sentence Length Histogram by Eojeol Token')
plt.xlabel('Sentence Length')
plt.ylabel('Number of Sentences')
# Out:
# Text(0, 0.5, 'Number of Sentences')

# %%
print('어절 최대길이: {}'.format(np.max(sent_len_by_token)))
print('어절 최소길이: {}'.format(np.min(sent_len_by_token)))
print('어절 평균길이: {:.2f}'.format(np.mean(sent_len_by_token)))
print('어절 길이 표준편차: {:.2f}'.format(np.std(sent_len_by_token)))
print('어절 중간길이: {}'.format(np.median(sent_len_by_token)))
print('제 1 사분위 길이: {}'.format(np.percentile(sent_len_by_token, 25)))
print('제 3 사분위 길이: {}'.format(np.percentile(sent_len_by_token, 75)))
# Out:
# 어절 최대길이: 21
# 어절 최소길이: 1
# 어절 평균길이: 3.64
# 어절 길이 표준편차: 1.74
# 어절 중간길이: 3.0
# 제 1 사분위 길이: 2.0
# 제 3 사분위 길이: 5.0

# %%
print('형태소 최대길이: {}'.format(np.max(sent_len_by_morph)))
print('형태소 최소길이: {}'.format(np.min(sent_len_by_morph)))
print('형태소 평균길이: {:.2f}'.format(np.mean(sent_len_by_morph)))
print('형태소 길이 표준편차: {:.2f}'.format(np.std(sent_len_by_morph)))
print('형태소 중간길이: {}'.format(np.median(sent_len_by_morph)))
print('형태소 1/4 퍼센타일 길이: {}'.format(np.percentile(sent_len_by_morph, 25)))
print('형태소 3/4 퍼센타일 길이: {}'.format(np.percentile(sent_len_by_morph, 75)))
# Out:
# 형태소 최대길이: 31
# 형태소 최소길이: 1
# 형태소 평균길이: 5.41
# 형태소 길이 표준편차: 2.56
# 형태소 중간길이: 5.0
# 형태소 1/4 퍼센타일 길이: 4.0
# 형태소 3/4 퍼센타일 길이: 7.0

# %%
print('음절 최대길이: {}'.format(np.max(sent_len_by_eumjeol)))
print('음절 최소길이: {}'.format(np.min(sent_len_by_eumjeol)))
print('음절 평균길이: {:.2f}'.format(np.mean(sent_len_by_eumjeol)))
print('음절 길이 표준편차: {:.2f}'.format(np.std(sent_len_by_eumjeol)))
print('음절 중간길이: {}'.format(np.median(sent_len_by_eumjeol)))
print('음절 1/4 퍼센타일 길이: {}'.format(np.percentile(sent_len_by_eumjeol, 25)))
print('음절 3/4 퍼센타일 길이: {}'.format(np.percentile(sent_len_by_eumjeol, 75)))
# Out:
# 음절 최대길이: 57
# 음절 최소길이: 1
# 음절 평균길이: 11.31
# 음절 길이 표준편차: 4.98
# 음절 중간길이: 10.0
# 음절 1/4 퍼센타일 길이: 8.0
# 음절 3/4 퍼센타일 길이: 14.0

# %%
plt.figure(figsize=(12, 5))
plt.boxplot([sent_len_by_token, sent_len_by_morph, sent_len_by_eumjeol],
            labels=['Eojeol', 'Morph', 'Eumjeol'], 
            showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1babc9d1c88>,
#   <matplotlib.lines.Line2D at 0x1babc7df508>,
#   <matplotlib.lines.Line2D at 0x1babc79fbc8>,
#   <matplotlib.lines.Line2D at 0x1babc7acd88>,
#   <matplotlib.lines.Line2D at 0x1babc6791c8>,
#   <matplotlib.lines.Line2D at 0x1babc7ddec8>],
#  'caps': [<matplotlib.lines.Line2D at 0x1babc7b0908>,
#   <matplotlib.lines.Line2D at 0x1babc7b0948>,
#   <matplotlib.lines.Line2D at 0x1babc7a8cc8>,
#   <matplotlib.lines.Line2D at 0x1babc7a8108>,
#   <matplotlib.lines.Line2D at 0x1babc7fe708>,
#   <matplotlib.lines.Line2D at 0x1babc7d7ec8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1babc7b05c8>,
#   <matplotlib.lines.Line2D at 0x1babc7e9748>,
#   <matplotlib.lines.Line2D at 0x1babc7ac188>],
#  'medians': [<matplotlib.lines.Line2D at 0x1babc79fb48>,
#   <matplotlib.lines.Line2D at 0x1babc7a8bc8>,
#   <matplotlib.lines.Line2D at 0x1babc7d7f88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1babc79ffc8>,
#   <matplotlib.lines.Line2D at 0x1babc795248>,
#   <matplotlib.lines.Line2D at 0x1babc790608>],
#  'means': [<matplotlib.lines.Line2D at 0x1babc79f808>,
#   <matplotlib.lines.Line2D at 0x1babc7a8d48>,
#   <matplotlib.lines.Line2D at 0x1babc790888>]}

# %% [markdown]
# ### 질문, 답변 각각의 문장 길이 분석

# %% [markdown]
# 형태소 단위로만 진행함

# %%
query_sentences = list(data['Q'])
answer_sentences = list(data['A'])

query_morph_tokenized_sentences = [okt.morphs(s.replace(' ', '')) for s in query_sentences]
query_sent_len_by_morph = [len(t) for t in query_morph_tokenized_sentences]

answer_morph_tokenized_sentences = [okt.morphs(s.replace(' ', '')) for s in answer_sentences]
answer_sent_len_by_morph = [len(t) for t in answer_morph_tokenized_sentences]

# %%
plt.figure(figsize=(12, 5))
plt.hist(query_sent_len_by_morph, bins=50, range=[0,50], color='g', label='Query')
plt.hist(answer_sent_len_by_morph, bins=50, range=[0,50], color='r', alpha=0.5, label='Answer')
plt.legend()
plt.title('Query Length Histogram by Morph Token')
plt.xlabel('Query Length')
plt.ylabel('Number of Queries')
# Out:
# Text(0, 0.5, 'Number of Queries')

# %%
plt.figure(figsize=(12, 5))
plt.hist(query_sent_len_by_morph, bins=50, range=[0,50], color='g', label='Query')
plt.hist(answer_sent_len_by_morph, bins=50, range=[0,50], color='r', alpha=0.5, label='Answer')
plt.legend()
plt.yscale('log', nonposy='clip')
plt.title('Query Length Log Histogram by Morph Token')
plt.xlabel('Query Length')
plt.ylabel('Number of Queries')
# Out:
# c:\users\lovd12\desktop\venv\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   """
# Text(0, 0.5, 'Number of Queries')

# %%
plt.figure(figsize=(12, 5))
plt.boxplot([query_sent_len_by_morph, answer_sent_len_by_morph],
            labels=['Query', 'Answer'], 
            showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1babdadb3c8>,
#   <matplotlib.lines.Line2D at 0x1babdad2c48>,
#   <matplotlib.lines.Line2D at 0x1babd829548>,
#   <matplotlib.lines.Line2D at 0x1babd937588>],
#  'caps': [<matplotlib.lines.Line2D at 0x1babd861b88>,
#   <matplotlib.lines.Line2D at 0x1babd80aa08>,
#   <matplotlib.lines.Line2D at 0x1babd86c6c8>,
#   <matplotlib.lines.Line2D at 0x1babd675c48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1babdad2a48>,
#   <matplotlib.lines.Line2D at 0x1babd81a088>],
#  'medians': [<matplotlib.lines.Line2D at 0x1babd650bc8>,
#   <matplotlib.lines.Line2D at 0x1babd8a4748>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1babd84bc48>,
#   <matplotlib.lines.Line2D at 0x1babd882b48>],
#  'means': [<matplotlib.lines.Line2D at 0x1babd85dec8>,
#   <matplotlib.lines.Line2D at 0x1babd850d08>]}

# %% [markdown]
# ### 데이터 어휘 빈도 분석

# %% [markdown]
# 품사에 따라 중요한 어휘(명사, 형용사, 동사)를 따로 모은 후 빈도수 분석을 진행함

# %%
query_NVA_token_sentences = list()
answer_NVA_token_sentences = list()

for s in query_sentences:
    for token, tag in okt.pos(s.replace(' ', '')):
        if tag == 'Noun' or tag == 'Verb' or tag == 'Adjective':
            query_NVA_token_sentences.append(token)

for s in answer_sentences:
    temp_token_bucket = list()
    for token, tag in okt.pos(s.replace(' ', '')):
        if tag == 'Noun' or tag == 'Verb' or tag == 'Adjective':
            answer_NVA_token_sentences.append(token)
            
query_NVA_token_sentences = ' '.join(query_NVA_token_sentences)
answer_NVA_token_sentences = ' '.join(answer_NVA_token_sentences)

# %% [markdown]
# #### 워드클라우드로 시각화

# %%
# 질문
query_wordcloud = WordCloud(font_path= DATA_IN_PATH + 'NanumGothic.ttf').generate(query_NVA_token_sentences)

plt.imshow(query_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# 답변
answer_wordcloud = WordCloud(font_path= DATA_IN_PATH + 'NanumGothic.ttf').generate(answer_NVA_token_sentences)

plt.imshow(answer_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# => 답변 데이터의 경우 질문 데이터와 마찬가지로 연애에 관한 단어가 많이 나오며 권유의 문자열이 자주 보인다
